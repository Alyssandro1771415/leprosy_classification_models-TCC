# %%
import sys
import os

sys.path.append(os.path.abspath('../..'))

# %%
from pipelines import process_image

# %%
raw_images_dir_binary = "/home/alyssandro/Documentos/Github/leprosy_classification_models-TCC/data/raw/train_images_binary"
raw_images_dir_classification = "/home/alyssandro/Documentos/Github/leprosy_classification_models-TCC/data/raw/train_images_classification"

# %%
processed_images_dir_binary = "/home/alyssandro/Documentos/Github/leprosy_classification_models-TCC/data/processed/train_images_binary"
processed_images_dir_classification = "/home/alyssandro/Documentos/Github/leprosy_classification_models-TCC/data/processed/train_images_classification"

# %%
for dir in os.listdir(raw_images_dir_binary):
    for file in os.listdir(raw_images_dir_binary+"/"+dir):
        process_image(raw_images_dir_binary+"/"+dir+"/"+file, processed_images_dir_binary+"/"+dir+"/"+file)

# %%
for dir in os.listdir(raw_images_dir_classification):
    for file in os.listdir(raw_images_dir_classification+"/"+dir):
        process_image(raw_images_dir_classification+"/"+dir+"/"+file, processed_images_dir_classification+"/"+dir+"/"+file)
